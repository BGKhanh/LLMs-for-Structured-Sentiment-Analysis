# %%
# !git clone https://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@github.com/BGKhanh/Reasoning-Techniques-on-LLM.git
# Out:
# Cloning into 'Reasoning-Techniques-on-LLM'...
# remote: Enumerating objects: 488, done.
# remote: Counting objects: 100% (156/156), done.
# remote: Compressing objects: 100% (103/103), done.
# remote: Total 488 (delta 94), reused 104 (delta 53), pack-reused 332 (from 1)
# Receiving objects: 100% (488/488), 833.87 KiB | 15.44 MiB/s, done.
# Resolving deltas: 100% (284/284), done.

# %%
# %cd /content/Reasoning-Techniques-on-LLM/
# Out:
# [Errno 2] No such file or directory: '/content/Reasoning-Techniques-on-LLM/'
# /kaggle/working

# %%
# !python inference.py --config /content/testing.yaml
# Out:
# python3: can't open file '/kaggle/working/inference.py': [Errno 2] No such file or directory
